# %%
# Import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load data
tinder_data_to_load = "Resources/Tinder_Millennial_Dataset.csv"

# %%
# Read csv
tinder_data = pd.read_csv(tinder_data_to_load)
pd.set_option('max_rows',None)
tinder_data
# Out:
#          ID Segment Type                      Segment Description  \
# 0    292881       Mobile                       Mobile respondents
# 1    292883       Mobile                       Mobile respondents
# 2    292885       Mobile                       Mobile respondents
# 3    292887          Web                    Web-based respondents
# 4    292889          Web                    Web-based respondents
# 5    292891          Web                    Web-based respondents
# 6    292893       Gender                         Male respondents
# 7    292895       Gender                         Male respondents
# 8    292897       Gender                         Male respondents
# 9    292899       Gender                       Female respondents
# 10   292901       Gender                       Female respondents
# 11   292903       Gender                       Female respondents
# 12   292905   University                       Chapman University
# ...

# %%
tinder_data.info
# Out:
# <bound method DataFrame.info of          ID Segment Type                      Segment Description  \
# 0    292881       Mobile                       Mobile respondents
# 1    292883       Mobile                       Mobile respondents
# 2    292885       Mobile                       Mobile respondents
# 3    292887          Web                    Web-based respondents
# 4    292889          Web                    Web-based respondents
# 5    292891          Web                    Web-based respondents
# 6    292893       Gender                         Male respondents
# 7    292895       Gender                         Male respondents
# 8    292897       Gender                         Male respondents
# 9    292899       Gender                       Female respondents
# 10   292901       Gender                       Female respondents
# 11   292903       Gender                       Female respondents
# 12   292905   University                       Chapman University
# ...

# %%
#tinder_data.info
# Out:
# <bound method DataFrame.info of          ID Segment Type    Segment Description              Answer  Count  \
# 0    292881       Mobile     Mobile respondents                 Yes    797
# 1    292883       Mobile     Mobile respondents                  No   1969
# 2    292885       Mobile     Mobile respondents  I don't use Tinder   1090
# 3    292887          Web  Web-based respondents                 Yes      0
# 4    292889          Web  Web-based respondents                  No      0
# ..      ...          ...                    ...                 ...    ...
# 448  293777   University         Boston College                  No      4
# 449  293779   University         Boston College  I don't use Tinder      1
# 450  293781   University      Boston University                 Yes      2
# 451  293783   University      Boston University                  No      3
# 452  293785   University      Boston University  I don't use Tinder      1
#
# ...

# %%
tinder_data.describe()
# Out:
#                   ID        Count  Percentage
# count     453.000000   453.000000  453.000000
# mean   293333.000000    22.373068    0.331141
# std       261.828188   136.996075    0.316157
# min    292881.000000     0.000000    0.000000
# 25%    293107.000000     0.000000    0.000000
# 50%    293333.000000     1.000000    0.250000
# 75%    293559.000000     4.000000    0.500000
# max    293785.000000  1969.000000    1.000000

# %%
category = ['Segment Type', 'Segment Description', 'Answer', 'It became a Relationship']
for column in category:
    print('Unique values in "{}" column count: {}'.format(column, tinder_data[column].nunique()))
    print(tinder_data[column].unique())
    print()
# Out:
# Unique values in "Segment Type" column count: 4
# ['Mobile' 'Web' 'Gender' 'University']
#
# Unique values in "Segment Description" column count: 151
# ['Mobile respondents' 'Web-based respondents' 'Male respondents'
#  'Female respondents' 'Chapman University' 'Cornell University'
#  'Duke University' 'George Washington University' 'Georgetown University'
#  'Harvard University' 'Indiana University' 'Johns Hopkins University'
#  'Northwestern University' 'Ohio State University' 'Princeton University'
#  'San Diego State University' 'Santa Clara University'
#  'Southern Methodist University' 'Stanford University' 'Tulane University'
#  'University of Pennsylvania' 'University of Wisconsin-Madison'
#  'University of Alabama' 'University of California, Berkeley'
#  'University of California, Davis' 'University of California, Los Angeles'
#  'University of California, Santa Barbara'
#  'University of Colorado Boulder' 'University of Miami'
# ...

# %%
# Convert answers for 'It became a relationship' column
dictionary = {'Yes':1, 'No':0}

# %%
# Only look at data from University of California, Davis
UCD_df = tinder_data[tinder_data["Segment Description"] == "University of California, Davis"]
UCD_df
# Out:
#         ID Segment Type              Segment Description              Answer  \
# 72  293025   University  University of California, Davis                 Yes
# 73  293027   University  University of California, Davis                  No
# 74  293029   University  University of California, Davis  I don't use Tinder
#
#     Count  Percentage It became a Relationship
# 72      3       0.176                      Yes
# 73      8       0.471                       No
# 74      6       0.353                       No

# %%
# Only look at data from University of California, Berkeley
UCB_df = tinder_data[tinder_data["Segment Description"] == "University of California, Berkeley"]
UCB_df
# Out:
#         ID Segment Type                 Segment Description  \
# 69  293019   University  University of California, Berkeley
# 70  293021   University  University of California, Berkeley
# 71  293023   University  University of California, Berkeley
#
#                 Answer  Count  Percentage It became a Relationship
# 69                 Yes     25       0.275                       No
# 70                  No     47       0.516                      Yes
# 71  I don't use Tinder     19       0.209                       No

# %%
# Only look at data from Santa Clara University
santa_clara_df = tinder_data[tinder_data["Segment Description"] == "Santa Clara University"]
santa_clara_df
# Out:
#         ID Segment Type     Segment Description              Answer  Count  \
# 48  292977   University  Santa Clara University                 Yes      0
# 49  292979   University  Santa Clara University                  No      4
# 50  292981   University  Santa Clara University  I don't use Tinder      1
#
#     Percentage It became a Relationship
# 48         0.0                      Yes
# 49         0.8                       No
# 50         0.2                       No

# %%
# Only look at data from Stanford University
stanford_df = tinder_data[tinder_data["Segment Description"] == "Stanford University"]
stanford_df
# Out:
#         ID Segment Type  Segment Description              Answer  Count  \
# 54  292989   University  Stanford University                 Yes     13
# 55  292991   University  Stanford University                  No     58
# 56  292993   University  Stanford University  I don't use Tinder     37
#
#     Percentage It became a Relationship
# 54       0.120                       No
# 55       0.537                       No
# 56       0.343                      Yes

# %%
# Only look at data from University of California, Santa Cruz
UCSC_df = tinder_data[tinder_data["Segment Description"] == "University of California, Santa Cruz"]
UCSC_df
# Out:
#          ID Segment Type                   Segment Description  \
# 216  293313   University  University of California, Santa Cruz
# 217  293315   University  University of California, Santa Cruz
# 218  293317   University  University of California, Santa Cruz
#
#                  Answer  Count  Percentage It became a Relationship
# 216                 Yes      2       0.667                      Yes
# 217                  No      1       0.333                       No
# 218  I don't use Tinder      0       0.000                       No

# %%
# Only look at data from Cal Poly San Luis Obispo
cal_poly_df = tinder_data[tinder_data["Segment Description"] == "Cal Poly San Luis Obispo"]
cal_poly_df
# Out:
#          ID Segment Type       Segment Description              Answer  Count  \
# 141  293163   University  Cal Poly San Luis Obispo                 Yes      8
# 142  293165   University  Cal Poly San Luis Obispo                  No     10
# 143  293167   University  Cal Poly San Luis Obispo  I don't use Tinder      7
#
#      Percentage It became a Relationship
# 141        0.32                       No
# 142        0.40                      Yes
# 143        0.28                       No

# %%
# Only look at data from University of California, Santa Barbara
UCSB_df = tinder_data[tinder_data["Segment Description"] == "University of California, Santa Barbara"]
UCSB_df
# Out:
#         ID Segment Type                      Segment Description  \
# 78  293037   University  University of California, Santa Barbara
# 79  293039   University  University of California, Santa Barbara
# 80  293041   University  University of California, Santa Barbara
#
#                 Answer  Count  Percentage It became a Relationship
# 78                 Yes     24       0.320                       No
# 79                  No     34       0.453                       No
# 80  I don't use Tinder     17       0.227                      Yes

# %%
# Only look at data from Cal State Northridge
CSUN_df = tinder_data[tinder_data["Segment Description"] == "Cal State Northridge"]
CSUN_df
# Out:
#          ID Segment Type   Segment Description              Answer  Count  \
# 342  293565   University  Cal State Northridge                 Yes      0
# 343  293567   University  Cal State Northridge                  No      2
# 344  293569   University  Cal State Northridge  I don't use Tinder      1
#
#      Percentage It became a Relationship
# 342       0.000                      Yes
# 343       0.667                       No
# 344       0.333                       No

# %%
# Only look at data from University of California, Los Angeles
UCLA_df = tinder_data[tinder_data["Segment Description"] == "University of California, Los Angeles"]
UCLA_df
# Out:
#         ID Segment Type                    Segment Description  \
# 75  293031   University  University of California, Los Angeles
# 76  293033   University  University of California, Los Angeles
# 77  293035   University  University of California, Los Angeles
#
#                 Answer  Count  Percentage It became a Relationship
# 75                 Yes      1       0.077                       No
# 76                  No      7       0.538                      Yes
# 77  I don't use Tinder      5       0.385                       No

# %%
# Only look at data from University of Southern California
USC_df = tinder_data[tinder_data["Segment Description"] == "University of Southern California"]
USC_df
# Out:
#         ID Segment Type                Segment Description  \
# 93  293067   University  University of Southern California
# 94  293069   University  University of Southern California
# 95  293071   University  University of Southern California
#
#                 Answer  Count  Percentage It became a Relationship
# 93                 Yes      1         0.1                       No
# 94                  No      7         0.7                      Yes
# 95  I don't use Tinder      2         0.2                       No

# %%
# Only look at data from University of California, San Diego
UCSD_df = tinder_data[tinder_data["Segment Description"] == "University of California, San Diego"]
UCSD_df
# Out:
#          ID Segment Type                  Segment Description  \
# 108  293097   University  University of California, San Diego
# 109  293099   University  University of California, San Diego
# 110  293101   University  University of California, San Diego
#
#                  Answer  Count  Percentage It became a Relationship
# 108                 Yes      1         1.0                      Yes
# 109                  No      0         0.0                       No
# 110  I don't use Tinder      0         0.0                       No

# %%
# Only look at data from San Diego State University
SDSU_df = tinder_data[tinder_data["Segment Description"] == "San Diego State University"]
SDSU_df
# Out:
#         ID Segment Type         Segment Description              Answer  \
# 45  292971   University  San Diego State University                 Yes
# 46  292973   University  San Diego State University                  No
# 47  292975   University  San Diego State University  I don't use Tinder
#
#     Count  Percentage It became a Relationship
# 45      5       0.192                       No
# 46     15       0.577                       No
# 47      6       0.231                       No

# %%
# Boxplot of match count 
plt.figure(figsize=(14,6))
sns.boxplot(x=df['Count'], y=df['It became a Relationship'].astype('category'))
plt.xscale('log')
plt.title('Boxplot of match counts')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-0d68491d57b6> in <module>
#       1 # Boxplot of match count
#       2 plt.figure(figsize=(14,6))
# ----> 3 sns.boxplot(x=df['Count'], y=df['It became a Relationship'].astype('category'))
#       4 plt.xscale('log')
#       5 plt.title('Boxplot of match counts')
#
# NameError: name 'sns' is not defined
